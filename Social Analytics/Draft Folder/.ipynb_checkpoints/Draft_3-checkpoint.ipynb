# %%
#Analyzing the news sentiment
#BBC, CBS, CNN, Fox, and New York times.
#The first plot: scatter from the pastt 100 tweets of each outlet, each plot is the comppound. sort by time stamp
#second plot: bar plot of overall sentiment of each outlet,  aggregate the compound sentiment

#Dependencies
import json
import tweepy
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time
from datetime import datetime
from textblob import TextBlob

#Keys to the kingdom
from config import Consumer
from config import ConsumerSecret
from config import Access
from config import AccessSecret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(Consumer, ConsumerSecret)
auth.set_access_token(Access, AccessSecret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

#Vader for the sentiment analytics
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
target_tags = ["@BBC", "@CBS", "@CNN", "@FoxNews","@nytimes"]

# %%
#counter = 0
#sentiments = []
#tweet_times = []
#converted_timestamps = []
#while counter < 4:
#    for tag in target_tags:
#        target_user = tag
#        for x in range(5):
#            public_tweets = api.user_timeline(target_user)
#            for tweet in public_tweets:
#                compound = analyzer.polarity_scores(tweet["text"])["compound"]
#                pos = analyzer.polarity_scores(tweet["text"])["pos"]
#                neu = analyzer.polarity_scores(tweet["text"])["neu"]
#                neg = analyzer.polarity_scores(tweet["text"])["neg"]
#                tweets_ago = counter
#                raw_time = tweet["created_at"]
#                tweet_times.append(raw_time)
#                for raw_time in tweet_times:
#                    converted_time = datetime.strptime(raw_time, "%a %b %d %H:%M:%S %z %Y")
#                    converted_timestamps.append(converted_time)
#                    print(analyzer.polarity_scores(tweet["text"]))
#                    sentiments.append({"Date": converted_timestamps, 
#                                       "Compound": compound,
#                                       "Positive": pos,
#                                       "Negative": neu,
#                                       "Neutral": neg,
#                                       "Outlet": tag,
#                                       "Tweets Ago": counter,})
#                    counter = counter + 1

# %%
counter = 0
sentiments = []
while counter < 4:
    for tag in target_tags:
        target_user = tag
        tweet_count = 0
        for x in range(1):
            public_tweets = api.user_timeline(target_user)
            for tweet in public_tweets:
                compound = analyzer.polarity_scores(tweet["text"])["compound"]
                pos = analyzer.polarity_scores(tweet["text"])["pos"]
                neu = analyzer.polarity_scores(tweet["text"])["neu"]
                neg = analyzer.polarity_scores(tweet["text"])["neg"]
                raw_time = tweet["created_at"]
                converted_time = datetime.strptime(raw_time, "%a %b %d %H:%M:%S %z %Y")
                print(analyzer.polarity_scores(tweet["text"]))
                sentiments.append({"Date": converted_time, 
                                   "Compound": compound,
                                   "Positive": pos,
                                   "Negative": neu,
                                   "Neutral": neg,
                                   "Outlet": tag,
                                   "Tweets Ago": tweet_count,})
                counter = counter + 1 
                tweet_count = tweet_count + 1
                converted_time = []
# Out:
# {'neg': 0.0, 'neu': 0.759, 'pos': 0.241, 'compound': 0.5859}
# {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.4019}
# {'neg': 0.09, 'neu': 0.697, 'pos': 0.213, 'compound': 0.4574}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.25}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.123, 'neu': 0.751, 'pos': 0.126, 'compound': 0.0258}
# {'neg': 0.099, 'neu': 0.901, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.109, 'neu': 0.697, 'pos': 0.194, 'compound': 0.4522}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.712, 'pos': 0.288, 'compound': 0.784}
# {'neg': 0.534, 'neu': 0.466, 'pos': 0.0, 'compound': -0.3164}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.108, 'neu': 0.68, 'pos': 0.212, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'compound': 0.296}
# {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compound': 0.508}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.786, 'pos': 0.214, 'compound': 0.7959}
# {'neg': 0.0, 'neu': 0.622, 'pos': 0.378, 'compound': 0.807}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.062, 'neu': 0.78, 'pos': 0.157, 'compound': 0.5319}
# {'neg': 0.0, 'neu': 0.801, 'pos': 0.199, 'compound': 0.5399}
# {'neg': 0.185, 'neu': 0.7, 'pos': 0.115, 'compound': -0.34}
# {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.7003}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.7184}
# {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.9451}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'compound': 0.6996}
# {'neg': 0.0, 'neu': 0.686, 'pos': 0.314, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.163, 'neu': 0.837, 'pos': 0.0, 'compound': -0.5994}
# {'neg': 0.16, 'neu': 0.739, 'pos': 0.101, 'compound': -0.2415}
# {'neg': 0.069, 'neu': 0.798, 'pos': 0.133, 'compound': 0.296}
# {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3182}
# {'neg': 0.128, 'neu': 0.722, 'pos': 0.15, 'compound': 0.1027}
# {'neg': 0.237, 'neu': 0.763, 'pos': 0.0, 'compound': -0.6808}
# {'neg': 0.208, 'neu': 0.691, 'pos': 0.102, 'compound': -0.3849}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.268, 'neu': 0.643, 'pos': 0.089, 'compound': -0.6143}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.6705}
# {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.802}
# {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'compound': 0.4215}
# {'neg': 0.147, 'neu': 0.671, 'pos': 0.182, 'compound': 0.0258}
# {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.296}
# {'neg': 0.13, 'neu': 0.651, 'pos': 0.219, 'compound': 0.128}
# {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4019}
# {'neg': 0.079, 'neu': 0.671, 'pos': 0.25, 'compound': 0.6523}
# {'neg': 0.0, 'neu': 0.729, 'pos': 0.271, 'compound': 0.6037}
# {'neg': 0.576, 'neu': 0.424, 'pos': 0.0, 'compound': -0.8591}
# {'neg': 0.295, 'neu': 0.705, 'pos': 0.0, 'compound': -0.5574}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.133, 'neu': 0.644, 'pos': 0.223, 'compound': 0.2732}
# {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.3818}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.328, 'neu': 0.522, 'pos': 0.149, 'compound': -0.5267}
# {'neg': 0.111, 'neu': 0.756, 'pos': 0.133, 'compound': 0.128}
# {'neg': 0.235, 'neu': 0.765, 'pos': 0.0, 'compound': -0.6486}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.341, 'neu': 0.509, 'pos': 0.149, 'compound': -0.5813}
# {'neg': 0.568, 'neu': 0.432, 'pos': 0.0, 'compound': -0.8481}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.6369}
# {'neg': 0.147, 'neu': 0.853, 'pos': 0.0, 'compound': -0.5849}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'compound': 0.296}
# {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.25}
# {'neg': 0.0, 'neu': 0.913, 'pos': 0.087, 'compound': 0.25}
# {'neg': 0.094, 'neu': 0.719, 'pos': 0.187, 'compound': 0.3818}
# {'neg': 0.247, 'neu': 0.709, 'pos': 0.044, 'compound': -0.7906}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.233, 'neu': 0.707, 'pos': 0.06, 'compound': -0.7096}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.055, 'neu': 0.718, 'pos': 0.227, 'compound': 0.7227}
# {'neg': 0.307, 'neu': 0.693, 'pos': 0.0, 'compound': -0.8555}
# {'neg': 0.257, 'neu': 0.743, 'pos': 0.0, 'compound': -0.6705}
# {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'compound': -0.5574}
# {'neg': 0.134, 'neu': 0.619, 'pos': 0.247, 'compound': 0.296}
# {'neg': 0.099, 'neu': 0.901, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
sentiments_pd = pd.DataFrame.from_dict(sentiments)
sentiments_pd.head()
# Out:
#    Compound                      Date  Negative  Neutral Outlet  Positive  \
# 0    0.5859 2018-03-30 13:05:00+00:00     0.759     0.00   @BBC     0.241
# 1    0.4019 2018-03-30 12:04:01+00:00     0.876     0.00   @BBC     0.124
# 2    0.4574 2018-03-30 10:39:54+00:00     0.697     0.09   @BBC     0.213
# 3    0.0000 2018-03-30 10:33:02+00:00     1.000     0.00   @BBC     0.000
# 4    0.2500 2018-03-30 10:03:04+00:00     0.909     0.00   @BBC     0.091
#
#    Tweets Ago
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4

# %%
sentiments_pd = sentiments_pd[["Outlet","Date", "Compound", "Positive", "Neutral", "Negative", "Tweets Ago"]]
sentiments_pd.tail()
# Out:
#       Outlet                      Date  Compound  Positive  Neutral  Negative  \
# 95  @nytimes 2018-03-30 12:19:12+00:00   -0.6705     0.000    0.257     0.743
# 96  @nytimes 2018-03-30 12:08:02+00:00   -0.5574     0.000    0.135     0.865
# 97  @nytimes 2018-03-30 12:00:27+00:00    0.2960     0.247    0.134     0.619
# 98  @nytimes 2018-03-30 11:46:01+00:00   -0.2960     0.000    0.099     0.901
# 99  @nytimes 2018-03-30 11:31:05+00:00    0.0000     0.000    0.000     1.000
#
#     Tweets Ago
# 95          15
# 96          16
# 97          17
# 98          18
# 99          19

# %%
sentiments_pd["Outlet"].unique()
# Out:
# array(['@BBC', '@CBS', '@CNN', '@FoxNews', '@nytimes'], dtype=object)

# %%
sentiments_pd.to_csv("sentiments_DF.csv", header = True)
